# %%
col1= "Display"
col2 = "Values"

col1 = "\""+col1+"\":"
col2 = "\""+col2+"\":"

title = "Test_Sort_by_3"
# title = "\""+title+"\":"

fields = "RW SJ Revenue, PW SJ Revenue, % SJ Revenue Change vs PW, L4W Avg SJ Revenue"
if ", "  in fields: 
    fields = fields.split(", ")
elif ","  in fields:
    fields = fields.split(",")

    

columntext = []
for i in range(len(fields)): 
    displayfields_asc = ("\""+fields[i]+" ⬆️\"")
    displayfields_desc = ("\""+fields[i]+" ⬇️\"")
    valuefields_asc = ("\"\'"+fields[i]+"\'"+" asc nulls last\"")
    valuefields_desc = ("\'"+fields[i]+"\' desc nulls last\"")
    columntext.append("{"+col1+displayfields_asc +"," + col2 + valuefields_asc + "},")
  
  
columntext = ''.join(columntext)

columntext = columntext[:-1]

fulltext= ('\"'+title+'\": {\"type\": \"staticflex\",\"numbers\": [],\"strings\": [],\"groups\": [],\"columns\": {'+col1+' {\"type\": \"string\"},'+col2+' {\"type\": \"string\"}},\"broadcastFacet\": true,\"selectMode\": \"single\",\"values\": [' + columntext+ '],\"label\": \"'+title+'\"},')

print(fulltext)
# import subprocess 
# subprocess.run("pbcopy", universal_newlines=True, input=fulltext)

# print("Query JSON copied to your clipboard, paste in your Dashboard")
# Out:
# "Test_Sort_by_3": {"type": "staticflex","numbers": [],"strings": [],"groups": [],"columns": {"Display": {"type": "string"},"Values": {"type": "string"}},"broadcastFacet": true,"selectMode": "single","values": [{"Display":"RW SJ Revenue ⬆️","Values":"'RW SJ Revenue' asc nulls last"},{"Display":"PW SJ Revenue ⬆️","Values":"'PW SJ Revenue' asc nulls last"},{"Display":"% SJ Revenue Change vs PW ⬆️","Values":"'% SJ Revenue Change vs PW' asc nulls last"},{"Display":"L4W Avg SJ Revenue ⬆️","Values":"'L4W Avg SJ Revenue' asc nulls last"}],"label": "Test_Sort_by_3"},

# %%
data = str(input("paste JSON here"))

# data = data.replace("'","\"")
# data = data.replace("False","false")


formatted_text = ('"steps": {'+fulltext)

final = data.replace("\"steps\": {",formatted_text)

print(final)

import subprocess 
subprocess.run("pbcopy", universal_newlines=True, input=final)

("Query JSON copied to your clipboard, paste in your Dashboard")
# Out:
# {     "label": "New dashboard",     "mobileDisabled": false,     "state": {         "steps": {"Test_Sort_by_3": {"type": "staticflex","numbers": [],"strings": [],"groups": [],"columns": {"Display": {"type": "string"},"Values": {"type": "string"}},"broadcastFacet": true,"selectMode": "single","values": [{"Display":"RW SJ Revenue ⬆️","Values":"'RW SJ Revenue' asc nulls last"},{"Display":"PW SJ Revenue ⬆️","Values":"'PW SJ Revenue' asc nulls last"},{"Display":"% SJ Revenue Change vs PW ⬆️","Values":"'% SJ Revenue Change vs PW' asc nulls last"},{"Display":"L4W Avg SJ Revenue ⬆️","Values":"'L4W Avg SJ Revenue' asc nulls last"}],"label": "Test_Sort_by_3"},             "Test_Sort_by_2": {                 "type": "staticflex",                 "numbers": [],                 "strings": [],                 "groups": [],                 "columns": {                     "Display": {                         "type": "string"                     },                     "Values": {                    
# ...

# %%
col1= input("column 1 name")
col2 = input("column 2 name")

col1 = "\""+col1+"\":"
col2 = "\""+col2+"\":"

title = input("query_name")

fields = input("comma separated list of fields to sort by")
if ", "  in fields: 
    fields = fields.split(", ")
elif ","  in fields:
    fields = fields.split(",")

    

columntext = []
for i in range(len(fields)): 
    displayfields_asc = ("\""+fields[i]+" ⬆️\"")
    displayfields_desc = ("\""+fields[i]+" ⬇️\"")
    valuefields_asc = ("\"\'"+fields[i]+"\'"+" asc nulls last\"")
    valuefields_desc = ("\'"+fields[i]+"\' desc nulls last\"")
    columntext.append("{"+col1+displayfields_asc +"," + col2 + valuefields_asc + "},")
  
  
columntext = ''.join(columntext)

columntext = columntext[:-1]

fulltext= ('\"'+title+'\": {\"type\": \"staticflex\",\"numbers\": [],\"strings\": [],\"groups\": [],\"columns\": {'+col1+' {\"type\": \"string\"},'+col2+' {\"type\": \"string\"}},\"broadcastFacet\": true,\"selectMode\": \"single\",\"values\": [' + columntext+ '],\"label\": \"'+title+'\"},')

print(fulltext)
# Out:
# column 1 nameArrows
# column 2 nameDescAsc
# query_nameMagic_Sort
# ...

# %%
data = str(input("paste JSON here"))

# data = data.replace("'","\"")
# data = data.replace("False","false")


formatted_text = ('"steps": {'+fulltext)

final = data.replace("\"steps\": {",formatted_text)

print(final)

import subprocess 
subprocess.run("pbcopy", universal_newlines=True, input=final)

("Query JSON copied to your clipboard, paste in your Dashboard")
# Out:
# paste JSON here{     "label": "[Marc Sprint Dev] Volume and Performance Dashboard",     "mobileDisabled": false,     "state": {         "dataSourceLinks": [             {                 "fields": [                     {                         "dataSourceName": "Users",                         "dataSourceType": "dataset",                         "fieldName": "MSR.Team_Name"                     },                     {                         "dataSourceName": "JobVolume",                         "dataSourceType": "dataset",                         "fieldName": "sales_team_name"                     }                 ],                 "label": "MSR.Sales_Team",                 "name": "Link_2073"             },             {                 "fields": [                     {                         "dataSourceName": "MyBookSummary_v2",                         "dataSourceType": "dataset",                         "fieldName": "Acc.Name"                     },                     {      
# ...
